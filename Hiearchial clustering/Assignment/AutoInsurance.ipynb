# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Insur1 = pd.read_csv("AutoInsurance.csv")
Insur1.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
Insur1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
from feature_engine.outliers import Winsorizer

# %%
winsor = Winsorizer(capping_method="iqr", tail = 'both', fold =1.5, variables=['Customer Lifetime Value','Income', 'Monthly Premium Auto',
       'Months Since Last Claim', 'Months Since Policy Inception',
       'Number of Open Complaints', 'Number of Policies','Total Claim Amount'])

# %%
Insur_prepro = winsor.fit_transform(Insur1[['Customer Lifetime Value','Income', 'Monthly Premium Auto',
       'Months Since Last Claim', 'Months Since Policy Inception',
       'Number of Open Complaints', 'Number of Policies','Total Claim Amount']])
Insur_prepro

# Preprocessing done
# Out:
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                 2763.519279  56274.0                  69.0
# 1                 6979.535903      0.0                  94.0
# 2                12887.431650  48767.0                 108.0
# 3                 7645.861827      0.0                 106.0
# 4                 2813.692575  43836.0                  73.0
# ...                       ...      ...                   ...
# 9129             16414.039912  71941.0                  73.0
# 9130              3096.511217  21604.0                  79.0
# 9131              8163.890428      0.0                  85.0
# 9132              7524.442436  21941.0                  96.0
# 9133              2611.836866      0.0                  77.0
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                        32.0                            5.0
# 1                        13.0                           42.0
# ...

# %%
Insur_prepro.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               7185.701022  37657.380009             91.494635
# std                4234.107132  30379.904734             28.416268
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               16414.039912  99981.000000            170.500000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
# normalization

def norm(i):
    x = (i-i.min())/(i.max()-i.min())
    return x

# %%
Insur_norm = norm(Insur_prepro)
Insur_norm = Insur_norm.drop(['Number of Open Complaints'], axis=1)
Insur_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer Lifetime Value        9134 non-null   float64
#  1   Income                         9134 non-null   float64
#  2   Monthly Premium Auto           9134 non-null   float64
#  3   Months Since Last Claim        9134 non-null   float64
#  4   Months Since Policy Inception  9134 non-null   float64
#  5   Number of Policies             9134 non-null   float64
#  6   Total Claim Amount             9134 non-null   float64
# dtypes: float64(7)
# memory usage: 499.6 KB

# %%
Insur_norm.describe()
# Out:
#        Customer Lifetime Value       Income  Monthly Premium Auto  \
# count              9134.000000  9134.000000           9134.000000
# mean                  0.364266     0.376645              0.278490
# std                   0.291685     0.303857              0.259509
# min                   0.000000     0.000000              0.000000
# 25%                   0.144409     0.000000              0.063927
# 50%                   0.267440     0.338959              0.200913
# 75%                   0.486645     0.623318              0.438356
# max                   1.000000     1.000000              1.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                  0.431343                       0.485501
# std                   0.287807                       0.281879
# min                   0.000000                       0.000000
# ...

# %%
#create the dendrogram

from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch

# %%
z = linkage(Insur_norm, method = 'ward', metric = 'euclidean')
z
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-40-7f42d552e07a> in <module>
# ----> 1 z = linkage(Insur_norm, method = 'ward', metric = 'euclidean')
#       2 z
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1050                          'matrix looks suspiciously like an uncondensed '
#    1051                          'distance matrix')
# -> 1052         y = distance.pdist(y, metric)
#    1053     else:
#    1054         raise ValueError("`y` must be 1 or 2 dimensional.")
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\spatial\distance.py in pdist(X, metric, *args, **kwargs)
#    1992     out = kwargs.pop("out", None)
#    1993     if out is None:
# -> 1994         dm = np.empty((m * (m - 1)) // 2, dtype=np.double)
#    1995     else:
# ...
